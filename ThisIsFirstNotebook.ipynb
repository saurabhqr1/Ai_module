# %% [markdown]
# # PYTHON

# %%
#this is comment !!
A = 3-1
print(A)
A
# Out:
# 2
# 2

# %%
#This is comment
x=3+5
print(x)
y=4+6
print(y)
# Out:
# 8
# 10

# %%
#This is comment
x=3+5
print(x)
# Out:
# 8

# %% [markdown]
# kuch likh sakte hai yaha

# %%
print(y)
# Out:
# 10

# %%
a,b = 4,5

# %%
a
# Out:
# 4

# %%
b
# Out:
# 5
