# %% [markdown]
# ### Pandas

# %%
import pandas as pd
import numpy as np
d1=(['a','b','c','d','e'])
S1=pd.Series(d1)
print(S1)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
import pandas as pd
import numpy as np
d1=['a','b','c','d','e']
S2=pd.Series(d1,index=[1, 2, 3, 4, 5])
print(S2)
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# 5    e
# dtype: object

# %%
import pandas as pd
import numpy as np
d3=({'name':'Tom','age':25,'mark':47})
S3=pd.Series(d3)
print(S3)
# Out:
# name    Tom
# age      25
# mark     47
# dtype: object

# %%
import pandas as pd
import numpy as np
d4={'Name':['jon','Jerry','Hash'
